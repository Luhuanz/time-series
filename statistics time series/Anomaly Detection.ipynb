# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import timedelta
from pandas.plotting import register_matplotlib_converters
#ACF 是一个完整的自相关函数，可为我们提供具有滞后值的任何序列的自相关值。
#ACF 考虑所有周期的相关性，PACF 则只考虑特定周期的相关性
#它描述了该序列的当前值与其过去的值之间的相关程度。 时间序列可以包含趋势，季节性，周期性和残差等成分。 ACF 在寻找相关性时会考虑所有这些成分。
from statsmodels.tsa.stattools import acf, pacf  
#SARIMAX 是在差分移动自回归模型（ARIMA）的基础上加上季节（S,Seasonal）和外部因素 (X,eXogenous)。也就是说以 ARIMA 基础加上周期性和季节性
from statsmodels.tsa.statespace.sarimax import SARIMAX
register_matplotlib_converters()
from time import time
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Catfish Sales Data

# %%
def parser(s):
    return datetime.strptime(s, '%Y-%m-%d')

# %%
#read data
catfish_sales = pd.read_csv('catfish.csv', parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)

# %%
catfish_sales
# Out:
# Date
# 1986-01-01     9034
# 1986-02-01     9596
# 1986-03-01    10558
# 1986-04-01     9002
# 1986-05-01     9239
#               ...
# 2012-08-01    14442
# 2012-09-01    13422
# 2012-10-01    13795
# 2012-11-01    13352
# 2012-12-01    12716
# Name: Total, Length: 324, dtype: int64

# %%
#infer the frequency of the data
catfish_sales = catfish_sales.asfreq(pd.infer_freq(catfish_sales.index))

# %%
catfish_sales.index
# Out:
# DatetimeIndex(['1986-01-01', '1986-02-01', '1986-03-01', '1986-04-01',
#                '1986-05-01', '1986-06-01', '1986-07-01', '1986-08-01',
#                '1986-09-01', '1986-10-01',
#                ...
#                '2012-03-01', '2012-04-01', '2012-05-01', '2012-06-01',
#                '2012-07-01', '2012-08-01', '2012-09-01', '2012-10-01',
#                '2012-11-01', '2012-12-01'],
#               dtype='datetime64[ns]', name='Date', length=324, freq=None)

# %%
#pd.infer_freq(catfish_sales.index) 来推断出该时间序列数据的采样频率（即时间间隔）
pd.infer_freq(catfish_sales.index) #表示时间序列数据按月进行采样，其中 "MS" 是 pandas 库中表示月初（Month Start）的一个字符串别名
# Out:
# 'MS'

# %%
catfish_sales.asfreq(pd.infer_freq(catfish_sales.index)) # asfreq() 函数来按照 MS 进行重新采样
# Out:
# Date
# 1986-01-01     9034
# 1986-02-01     9596
# 1986-03-01    10558
# 1986-04-01     9002
# 1986-05-01     9239
#               ...
# 2012-08-01    14442
# 2012-09-01    13422
# 2012-10-01    13795
# 2012-11-01    13352
# 2012-12-01    12716
# Freq: MS, Name: Total, Length: 324, dtype: int64

# %%
datetime(1996,1,1) #年 月 日 时 分
# Out:
# datetime.datetime(1996, 1, 1, 0, 0)

# %%
start_date = datetime(1996,1,1)
end_date = datetime(2000,1,1)
lim_catfish_sales = catfish_sales[start_date:end_date]

# %%
lim_catfish_sales.head(10)
# Out:
# Date
# 1996-01-01    20322
# 1996-02-01    20613
# 1996-03-01    22704
# 1996-04-01    20276
# 1996-05-01    20669
# 1996-06-01    18074
# 1996-07-01    18719
# 1996-08-01    20217
# 1996-09-01    19642
# 1996-10-01    20842
# Name: Total, dtype: int64

# %% [markdown]
# Introduce an Anomaly

# %%
#At December 1 1998
lim_catfish_sales[datetime(1998,12,1)] = 10000

# %%
plt.figure(figsize=(10,4))
plt.plot(lim_catfish_sales)
plt.title('Catfish Sales in 1000s of Pounds', fontsize=20)
plt.ylabel('Sales', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)

# %% [markdown]
# ## Remove the trend

# %%
lim_catfish_sales.diff().head() # 中相邻数据之间的差分
# Out:
# Date
# 1996-01-01       NaN
# 1996-02-01     291.0
# 1996-03-01    2091.0
# 1996-04-01   -2428.0
# 1996-05-01     393.0
# Name: Total, dtype: float64

# %%
first_diff = lim_catfish_sales.diff()[1:]

# %%
first_diff.head()
# Out:
# Date
# 1996-02-01     291.0
# 1996-03-01    2091.0
# 1996-04-01   -2428.0
# 1996-05-01     393.0
# 1996-06-01   -2595.0
# Name: Total, dtype: float64

# %%
plt.figure(figsize=(10,4))
plt.plot(first_diff)
plt.title('Catfish Sales in 1000s of Pounds', fontsize=20)
plt.ylabel('Sales', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)
plt.axhline(0, color='k', linestyle='--', alpha=0.2)

# %% [markdown]
# # Get training and testing sets

# %%
train_end = datetime(1999,7,1)
test_end = datetime(2000,1,1)

test_data = lim_catfish_sales[train_end + timedelta(days=1):test_end]

# %% [markdown]
# # Make Predictions

# %%
test_data
# Out:
# Date
# 1999-08-01    24618
# 1999-09-01    24430
# 1999-10-01    25229
# 1999-11-01    22344
# 1999-12-01    22372
# 2000-01-01    25412
# Name: Total, dtype: int64

# %%
my_order = (0,1,0)
my_seasonal_order = (1, 0, 1, 12)

# %%
my_seasonal_order
# Out:
# (1, 0, 1, 12)

# %%
test_data.index
# Out:
# DatetimeIndex(['1999-08-01', '1999-09-01', '1999-10-01', '1999-11-01',
#                '1999-12-01', '2000-01-01'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
lim_catfish_sales[:train_end-timedelta(days=1)] #从序列的开始位置到当前 train_end 时间点前一月的所有数据。
# Out:
# Date
# 1996-01-01    20322
# 1996-02-01    20613
# 1996-03-01    22704
# 1996-04-01    20276
# 1996-05-01    20669
# 1996-06-01    18074
# 1996-07-01    18719
# 1996-08-01    20217
# 1996-09-01    19642
# 1996-10-01    20842
# 1996-11-01    18204
# 1996-12-01    16898
# 1997-01-01    20746
# 1997-02-01    23058
# 1997-03-01    24624
# 1997-04-01    22154
# 1997-05-01    22444
# 1997-06-01    21471
# 1997-07-01    21866
# 1997-08-01    22548
# 1997-09-01    21518
# 1997-10-01    23408
# 1997-11-01    19645
# 1997-12-01    18278
# 1998-01-01    23576
# 1998-02-01    26650
# 1998-03-01    26207
# 1998-04-01    23195
# 1998-05-01    22960
# 1998-06-01    23002
# 1998-07-01    22973
# 1998-08-01    24089
# 1998-09-01    22805
# 1998-10-01    23241
# 1998-11-01    21581
# 1998-12-01    10000
# 1999-01-01    23107
# 1999-02-01    25780
# 1999-03-01    28544
# 1999-04-01    23488
# 1999-05-01    23964
# 1999-06-01    23720
# 1999-07-01    25069
# 1999-08-01    24618
# 1999-09-01    24430
# 1999-10-01    25229
# 1999-11-01    22344
# 1999-12-01    22372
# Name: Total, dtype: int64

# %%
#采用 SARIMA 模型，用于预测时间序列数据在未来若干时间点上的值。
rolling_predictions = test_data.copy() #先创建了一个名为 rolling_predictions 的 DataFrame 对象，用于存储预测结果。
for train_end in test_data.index:
    train_data = lim_catfish_sales[:train_end-timedelta(days=1)] #对于 test_data 中的每个时间点（即索引），从历史数据 lim_catfish_sales 中提取训练数据
    model = SARIMAX(train_data, order=my_order, seasonal_order=my_seasonal_order) #使用 SARIMA 模型对这些数据进行拟合和预测
    model_fit = model.fit()

    pred = model_fit.forecast() #预测的结果 pred 将被存储在 rolling_predictions 中相应时间点的位置上
    rolling_predictions[train_end] = pred
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.09218D+01    |proj g|=  2.83055D+00
#
# At iterate    5    f=  9.78346D+00    |proj g|=  1.48851D-01
#
# At iterate   10    f=  9.65313D+00    |proj g|=  2.11382D-02
#
# At iterate   15    f=  9.63555D+00    |proj g|=  5.45298D-03
#
# At iterate   20    f=  9.53907D+00    |proj g|=  1.05034D-03
#
# At iterate   25    f=  9.21705D+00    |proj g|=  8.13659D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     28     32      1     0     0   7.620D-06   9.217D+00
#   F =   9.2169957491134173
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.15510D+01    |proj g|=  3.46330D+00
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  9.93957D+00    |proj g|=  7.66380D-02
#
# At iterate   10    f=  9.85334D+00    |proj g|=  3.76585D-03
#
# At iterate   15    f=  9.71592D+00    |proj g|=  1.27435D-01
#
# At iterate   20    f=  9.21124D+00    |proj g|=  8.69466D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     24     29      1     0     0   8.155D-07   9.211D+00
#   F =   9.2107173139846665
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05000D+01    |proj g|=  3.55961D-01
#  This problem is unconstrained.
# At iterate    5    f=  9.12099D+00    |proj g|=  1.02721D-03
#
# At iterate   10    f=  9.11854D+00    |proj g|=  3.35793D-02
#
# At iterate   15    f=  9.10856D+00    |proj g|=  2.44096D-02
#
# At iterate   20    f=  9.10604D+00    |proj g|=  3.31930D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     22     41      1     0     0   7.988D-04   9.106D+00
#   F =   9.1059976158819929
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.02638D+01    |proj g|=  5.50938D-01
#
# At iterate    5    f=  9.25058D+00    |proj g|=  8.50430D-02
#
# At iterate   10    f=  9.20198D+00    |proj g|=  3.29776D-02
#
# At iterate   15    f=  9.18024D+00    |proj g|=  2.43253D-02
#
# At iterate   20    f=  9.16574D+00    |proj g|=  9.58442D-03
#   ys=-2.291E-02  -gs= 3.062E-03 BFGS update SKIPPED
#
# At iterate   25    f=  9.15506D+00    |proj g|=  5.88650D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     27     91      1     1     0   5.859D-03   9.154D+00
#   F =   9.1542911214186180
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.04058D+01    |proj g|=  2.27884D+00
#
# At iterate    5    f=  9.53177D+00    |proj g|=  9.33728D-02
#
# At iterate   10    f=  9.47350D+00    |proj g|=  2.75916D-03
#
# At iterate   15    f=  9.43594D+00    |proj g|=  5.94237D-03
#
# At iterate   20    f=  9.20018D+00    |proj g|=  1.05414D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     23     26      1     0     0   1.872D-07   9.200D+00
#   F =   9.2000887749800331
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00746D+01    |proj g|=  1.78266D+00
#
# At iterate    5    f=  9.68495D+00    |proj g|=  8.14613D-01
#
# At iterate   10    f=  9.29053D+00    |proj g|=  1.41673D-01
#
# At iterate   15    f=  9.17739D+00    |proj g|=  3.86946D-02
#
# At iterate   20    f=  9.15050D+00    |proj g|=  2.91330D-02
#
# At iterate   25    f=  9.12423D+00    |proj g|=  1.77266D-03
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# At iterate   30    f=  9.07126D+00    |proj g|=  2.56797D-01
#   ys=-1.235E-11  -gs= 6.323E-12 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     31    118      3     1     0   2.568D-01   9.071D+00
#   F =   9.0712632455316502
#
# ABNORMAL_TERMINATION_IN_LNSRCH

# %%
rolling_predictions
# Out:
# Date
# 1999-08-01    25745.165078
# 1999-09-01    24182.121714
# 1999-10-01    25287.608246
# 1999-11-01    23219.249044
# 1999-12-01    16107.849184
# 2000-01-01    29756.194226
# Name: Total, dtype: float64

# %%
 rolling_predictions
# Out:
# Date
# 1999-08-01    25745.165078
# 1999-09-01    24182.121714
# 1999-10-01    25287.608246
# 1999-11-01    23219.249044
# 1999-12-01    16107.849184
# 2000-01-01    29756.194226
# Name: Total, dtype: float64

# %%
 test_data
# Out:
# Date
# 1999-08-01    24618
# 1999-09-01    24430
# 1999-10-01    25229
# 1999-11-01    22344
# 1999-12-01    22372
# 2000-01-01    25412
# Name: Total, dtype: int64

# %%
rolling_residuals = test_data - rolling_predictions

# %%
plt.figure(figsize=(10,4))
plt.plot(rolling_residuals)
plt.axhline(0, linestyle='--', color='k')
plt.title('Rolling Forecast Residuals from SARIMA Model', fontsize=20)
plt.ylabel('Error', fontsize=16)
# Out:
# Text(0, 0.5, 'Error')

# %%
plt.figure(figsize=(10,4))

plt.plot(lim_catfish_sales)
plt.plot(rolling_predictions)

plt.legend(('Data', 'Predictions'), fontsize=16)

plt.title('Catfish Sales in 1000s of Pounds', fontsize=20)
plt.ylabel('Production', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)

# %%
print('Mean Absolute Percent Error:', round(np.mean(abs(rolling_residuals/test_data)),4))
# Out:
# Mean Absolute Percent Error: 0.0914

# %%
print('Root Mean Squared Error:', np.sqrt(np.mean(rolling_residuals**2)))
# Out:
# Root Mean Squared Error: 3167.887032233898

# %% [markdown]
# # Detecting the Anomaly 检测异常

# %% [markdown]
# ## Attempt 1: Deviation Method 偏差法

# %%
plt.figure(figsize=(10,4))
plt.plot(lim_catfish_sales)
plt.title('Catfish Sales in 1000s of Pounds', fontsize=20)
plt.ylabel('Sales', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)

# %%
rolling_deviations = pd.Series(dtype=float, index = lim_catfish_sales.index)

# %%
rolling_deviations
# Out:
# Date
# 1996-01-01   NaN
# 1996-02-01   NaN
# 1996-03-01   NaN
# 1996-04-01   NaN
# 1996-05-01   NaN
# 1996-06-01   NaN
# 1996-07-01   NaN
# 1996-08-01   NaN
# 1996-09-01   NaN
# 1996-10-01   NaN
# 1996-11-01   NaN
# 1996-12-01   NaN
# 1997-01-01   NaN
# 1997-02-01   NaN
# 1997-03-01   NaN
# 1997-04-01   NaN
# 1997-05-01   NaN
# 1997-06-01   NaN
# 1997-07-01   NaN
# 1997-08-01   NaN
# 1997-09-01   NaN
# 1997-10-01   NaN
# 1997-11-01   NaN
# 1997-12-01   NaN
# 1998-01-01   NaN
# 1998-02-01   NaN
# 1998-03-01   NaN
# 1998-04-01   NaN
# 1998-05-01   NaN
# 1998-06-01   NaN
# 1998-07-01   NaN
# 1998-08-01   NaN
# 1998-09-01   NaN
# 1998-10-01   NaN
# 1998-11-01   NaN
# 1998-12-01   NaN
# 1999-01-01   NaN
# 1999-02-01   NaN
# 1999-03-01   NaN
# 1999-04-01   NaN
# 1999-05-01   NaN
# 1999-06-01   NaN
# 1999-07-01   NaN
# 1999-08-01   NaN
# 1999-09-01   NaN
# 1999-10-01   NaN
# 1999-11-01   NaN
# 1999-12-01   NaN
# 2000-01-01   NaN
# dtype: float64

# %%
for date in rolling_deviations.index:
    #get the window ending at this data point
    window = lim_catfish_sales.loc[:date]
    
    #get the deviation within this window
    rolling_deviations.loc[date] = window.std()

# %%
#get the difference in deviation between one time point and the next
diff_rolling_deviations = rolling_deviations.diff()
diff_rolling_deviations = diff_rolling_deviations.dropna()

# %%
plt.figure(figsize=(10,4))
plt.plot(diff_rolling_deviations)
plt.title('Deviation Differences', fontsize=20)
plt.ylabel('Sales', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)

# %% [markdown]
# ## Attempt 2: Seasonal Method

# %%
month_deviations = lim_catfish_sales.groupby(lambda d: d.month).std()

# %%
plt.figure(figsize=(10,4))
plt.plot(month_deviations)
plt.title('Deviation by Month', fontsize=20)
plt.ylabel('Sales', fontsize=16)
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ## So, the anomaly occurs in a December

# %%
december_data = lim_catfish_sales[lim_catfish_sales.index.month == 12]

# %%
december_data
# Out:
# Date
# 1996-12-01    16898
# 1997-12-01    18278
# 1998-12-01    10000
# 1999-12-01    22372
# Name: Total, dtype: int64

# %%
min_dev = 9999999
curr_anomaly = None
for date in december_data.index:
    other_data = december_data[december_data.index != date]
    curr_dev = other_data.std()
    if curr_dev < min_dev:
        min_dev = curr_dev
        curr_anomaly = date

# %%
curr_anomaly
# Out:
# Timestamp('1998-12-01 00:00:00')

# %% [markdown]
# # What to do about the anomaly? 如何处理这个异常现象

# %% [markdown]
# ## Simple Idea: use mean of other months

# %%
adjusted_data = lim_catfish_sales.copy()
adjusted_data.loc[curr_anomaly] = december_data[(december_data.index != curr_anomaly) & (december_data.index < test_data.index[0])].mean()

# %%
plt.figure(figsize=(10,4))
plt.plot(lim_catfish_sales, color='firebrick', alpha=0.4)
plt.plot(adjusted_data)
plt.title('Catfish Sales in 1000s of Pounds', fontsize=20)
plt.ylabel('Sales', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)
plt.axvline(curr_anomaly, color='k', alpha=0.7)

# %% [markdown]
# # Resulting Predictions

# %%
train_end = datetime(1999,7,1)
test_end = datetime(2000,1,1)

test_data = adjusted_data[train_end + timedelta(days=1):test_end]

# %%
rolling_predictions = test_data.copy()
for train_end in test_data.index:
    train_data = adjusted_data[:train_end-timedelta(days=1)]
    model = SARIMAX(train_data, order=my_order, seasonal_order=my_seasonal_order)
    model_fit = model.fit()

    pred = model_fit.forecast()
    rolling_predictions[train_end] = pred
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.37726D+00    |proj g|=  2.32149D+00
#
# At iterate    5    f=  8.78921D+00    |proj g|=  5.06563D-01
#
# At iterate   10    f=  8.54786D+00    |proj g|=  6.80124D-02
#
# At iterate   15    f=  8.53240D+00    |proj g|=  5.11901D-03
#
# At iterate   20    f=  8.53142D+00    |proj g|=  6.09956D-03
#
# At iterate   25    f=  8.53140D+00    |proj g|=  7.32556D-04
#
# At iterate   30    f=  8.53112D+00    |proj g|=  1.00675D-02
#
# At iterate   35    f=  8.52893D+00    |proj g|=  6.58001D-04
#  This problem is unconstrained.
# At iterate   40    f=  8.52887D+00    |proj g|=  1.29918D-03
#
# At iterate   45    f=  8.52883D+00    |proj g|=  6.86178D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     46     69      1     0     0   5.517D-05   8.529D+00
#   F =   8.5288296843046130
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.22862D+00    |proj g|=  1.98274D+00
#
# At iterate    5    f=  8.72055D+00    |proj g|=  4.96083D-01
#  This problem is unconstrained.
# At iterate   10    f=  8.54998D+00    |proj g|=  6.00592D-02
#
# At iterate   15    f=  8.53844D+00    |proj g|=  6.22298D-03
#
# At iterate   20    f=  8.53820D+00    |proj g|=  9.32584D-05
#
# At iterate   25    f=  8.53811D+00    |proj g|=  6.85701D-03
#
# At iterate   30    f=  8.53018D+00    |proj g|=  3.25643D-02
#
# At iterate   35    f=  8.52884D+00    |proj g|=  7.92565D-04
#
# At iterate   40    f=  8.52877D+00    |proj g|=  3.95872D-04
#
# At iterate   45    f=  8.52871D+00    |proj g|=  2.40942D-03
#
# At iterate   50    f=  8.52868D+00    |proj g|=  1.10467D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     50     68      1     0     0   1.105D-03   8.529D+00
#   F =   8.5286762577650350
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.79266D+00    |proj g|=  8.29519D-01
#
# At iterate    5    f=  8.55499D+00    |proj g|=  6.26236D-02
#
# At iterate   10    f=  8.54637D+00    |proj g|=  3.88202D-03
#  This problem is unconstrained.
# At iterate   15    f=  8.54633D+00    |proj g|=  5.69540D-04
#
# At iterate   20    f=  8.54626D+00    |proj g|=  5.29513D-03
#
# At iterate   25    f=  8.53947D+00    |proj g|=  7.75231D-02
#
# At iterate   30    f=  8.52157D+00    |proj g|=  8.93805D-03
#
# At iterate   35    f=  8.52101D+00    |proj g|=  6.67545D-03
#
# At iterate   40    f=  8.52084D+00    |proj g|=  5.49731D-03
#
# At iterate   45    f=  8.52077D+00    |proj g|=  3.68388D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     48     68      1     0     0   7.045D-04   8.521D+00
#   F =   8.5207453407595448
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.18299D+00    |proj g|=  1.89255D+00
#
# At iterate    5    f=  8.69977D+00    |proj g|=  4.78022D-01
#
# At iterate   10    f=  8.53613D+00    |proj g|=  5.50579D-02
#
# At iterate   15    f=  8.52585D+00    |proj g|=  4.72462D-03
#  This problem is unconstrained.
# At iterate   20    f=  8.52572D+00    |proj g|=  1.15982D-04
#
# At iterate   25    f=  8.52560D+00    |proj g|=  5.18691D-03
#
# At iterate   30    f=  8.51409D+00    |proj g|=  4.28460D-03
#
# At iterate   35    f=  8.51163D+00    |proj g|=  4.16140D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     35     45      1     0     0   4.161D-04   8.512D+00
#   F =   8.5116295569516502
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.11364D+00    |proj g|=  1.66079D+00
#
# At iterate    5    f=  8.69853D+00    |proj g|=  5.10710D-01
#  This problem is unconstrained.
# At iterate   10    f=  8.54783D+00    |proj g|=  3.34767D-02
#
# At iterate   15    f=  8.54205D+00    |proj g|=  3.22247D-03
#
# At iterate   20    f=  8.54149D+00    |proj g|=  1.00917D-03
#
# At iterate   25    f=  8.51188D+00    |proj g|=  3.14167D-02
#
# At iterate   30    f=  8.50924D+00    |proj g|=  5.88782D-04
#
# At iterate   35    f=  8.50908D+00    |proj g|=  3.15899D-04
#
# At iterate   40    f=  8.50899D+00    |proj g|=  2.03804D-03
#
# At iterate   45    f=  8.50896D+00    |proj g|=  2.70566D-03
#   ys=-7.817E-05  -gs= 1.353E-05 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     48     90      2     1     0   1.467D-05   8.509D+00
#   F =   8.5089484730711078
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.74939D+00    |proj g|=  6.91699D-01
#
# At iterate    5    f=  8.58379D+00    |proj g|=  3.51527D-02
#
# At iterate   10    f=  8.57061D+00    |proj g|=  6.07287D-03
#
# At iterate   15    f=  8.57050D+00    |proj g|=  4.07568D-04
#
# At iterate   20    f=  8.57043D+00    |proj g|=  1.83112D-03
#
# At iterate   25    f=  8.56362D+00    |proj g|=  6.09398D-02
#
# At iterate   30    f=  8.51577D+00    |proj g|=  5.06718D-03
#
# At iterate   35    f=  8.51562D+00    |proj g|=  3.26641D-03
#
# At iterate   40    f=  8.51552D+00    |proj g|=  1.01572D-03
#
# At iterate   45    f=  8.51551D+00    |proj g|=  6.15730D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     48     80      1     0     0   4.764D-04   8.516D+00
#   F =   8.5155087294004108
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.

# %%
rolling_residuals = test_data - rolling_predictions

# %%
plt.figure(figsize=(10,4))
plt.plot(rolling_residuals)
plt.axhline(0, linestyle='--', color='k')
plt.title('Rolling Forecast Residuals from SARIMA Model', fontsize=20)
plt.ylabel('Error', fontsize=16)
# Out:
# Text(0, 0.5, 'Error')

# %%
plt.figure(figsize=(10,4))

plt.plot(lim_catfish_sales)
plt.plot(rolling_predictions)

plt.legend(('Data', 'Predictions'), fontsize=16)

plt.title('Catfish Sales in 1000s of Pounds', fontsize=20)
plt.ylabel('Production', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)

# %%
print('Mean Absolute Percent Error:', round(np.mean(abs(rolling_residuals/test_data)),4))
# Out:
# Mean Absolute Percent Error: 0.0461

# %%
print('Root Mean Squared Error:', np.sqrt(np.mean(rolling_residuals**2)))
# Out:
# Root Mean Squared Error: 1327.740964888891
